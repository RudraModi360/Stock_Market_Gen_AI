# %%
import json

file=open("NSE.json")
data=json.load(file)
data
# Out:
# [{'weekly': False,
#   'segment': 'NSE_FO',
#   'name': 'ADITYA BIRLA FASHION & RT',
#   'exchange': 'NSE',
#   'expiry': 1724956199000,
#   'instrument_type': 'PE',
#   'asset_symbol': 'ABFRL',
#   'underlying_symbol': 'ABFRL',
#   'instrument_key': 'NSE_FO|49902',
#   'lot_size': 2600,
#   'freeze_quantity': 78000.0,
#   'exchange_token': '49902',
#   'minimum_lot': 2600,
#   'asset_key': 'NSE_EQ|INE647O01011',
#   'underlying_key': 'NSE_EQ|INE647O01011',
#   'tick_size': 5.0,
#   'asset_type': 'EQUITY',
#   'underlying_type': 'EQUITY',
#   'trading_symbol': 'ABFRL 355 PE 29 AUG 24',
#   'strike_price': 355.0},
#  {'weekly': False,
#   'segment': 'NSE_FO',
#   'name': 'GUJARAT GAS LIMITED',
#   'exchange': 'NSE',
#   'expiry': 1721932199000,
#   'instrument_type': 'FUT',
#   'asset_symbol': 'GUJGASLTD',
#   'underlying_symbol': 'GUJGASLTD',
#   'instrument_key': 'NSE_FO|49900',
#   'lot_size': 1250,
#   'freeze_quantity': 37500.0,
#   'exchange_token': '49900',
# ...
